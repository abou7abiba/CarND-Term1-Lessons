# %% [markdown]
# # Measuring Curvature
#
# First we genearte data to use for testing the curvature equation using the `geerate_data()` method and then we plot this data to show the sample lane.
#
# Then we use the input data to calculate the curvature. We use the python file in [curve_pixels_quiz.py][curve_pixels_quiz.py]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# import functions implemented in [curve_pixels_quiz.py][curve_pixels_quiz.py]

# %%
import os
import sys
sys.path.append(os.path.abspath("curve_pixels_quiz.py"))

from curve_pixels_quiz import *

# %%
left_curverad, right_curverad = measure_curvature_pixels()
print(left_curverad, right_curverad)
# Out:
# 1625.0601831657184 1976.2967307714246

# %%
left_curverad, right_curverad = measure_curvature_real()
print(left_curverad, right_curverad)
# Out:
# 533.7525889210929 648.1574851434267

# %%
# Start by generating our fake example data
# Make sure to feed in your real data instead in your project!
ploty, leftx, rightx, left_fit, right_fit = generate_data (1, 1)

left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
print (left_fit)
print (right_fit)

# Plot up the fake data
mark_size = 3
plt.plot(leftx, ploty, 'o', color='red', markersize=mark_size)
plt.plot(rightx, ploty, 'o', color='blue', markersize=mark_size)
plt.xlim(0, 1280)
plt.ylim(0, 720)
plt.plot(left_fitx, ploty, color='green', linewidth=3)
plt.plot(right_fitx, ploty, color='green', linewidth=3)
plt.gca().invert_yaxis() # to visualize as we do the images
# Out:
# [ 3.07683280e-04 -4.44713275e-01  3.59067572e+02]
# [ 2.53380891e-04 -3.96103079e-01  1.04908806e+03]

# %%
# Define conversions in x and y from pixels space to meters
ym_per_pix = 30/720 # meters per pixel in y dimension
xm_per_pix = 3.7/700 # meters per pixel in x dimension
    

# Start by generating our fake example data
# Make sure to feed in your real data instead in your project!
ploty, leftx, rightx, left_fit, right_fit = generate_data_2 (ym_per_pix, xm_per_pix)

left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
print (left_fit)
print (right_fit)

# Plot up the fake data
mark_size = 3
plt.plot(leftx, ploty, 'o', color='red', markersize=mark_size)
plt.plot(rightx, ploty, 'o', color='blue', markersize=mark_size)
plt.xlim(0, xm_per_pix * 1280)
plt.ylim(0, ym_per_pix * 720)
plt.plot(left_fitx, ploty, color='green', linewidth=3)
plt.plot(right_fitx, ploty, color='green', linewidth=3)
plt.gca().invert_yaxis() # to visualize as we do the images
# Out:
# (0.0009367637221485669, -0.0564150554811018, 1.8979285946960627)
# (0.0007714362199771765, -0.050248504893205766, 5.5451797665454094)
